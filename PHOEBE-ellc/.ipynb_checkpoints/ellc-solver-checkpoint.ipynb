# %%
import phoebe
from phoebe import u
import numpy as np
import matplotlib.pyplot as plt
from ellc import ldy,lc
logger = phoebe.logger('error')
# %matplotlib inline

# %%
phoebe.__version__
# Out:
# '2.4.9'

# %% [markdown]
# ### fake observations

# %%
orig = phoebe.default_binary()

#b['period@orbit'] = 0.5
#b['sma@orbit'] = 3.5
orig.set_value('ecc', 0.2)
orig.set_value('per0', 25)
orig.set_value('teff@primary', 6500)
orig.set_value('teff@secondary', 5500)
orig.set_value('sma@binary', 7)
orig.set_value('incl@binary', 83.5)
orig.set_value('q', 0.66)
orig.set_value('t0_supconj', 0.1)
orig.set_value('requiv@primary', 1.3)
orig.set_value('requiv@secondary', 0.9)
orig.set_value('vgamma', 80)

lctimes = phoebe.linspace(0, 10, 1005)
rvtimes = phoebe.linspace(0, 10, 105)
orig.add_dataset('lc', compute_times=lctimes)
orig.add_dataset('rv', compute_times=rvtimes)

orig.add_compute('ellc', compute='fastcompute')
orig.set_value_all('ld_mode', 'lookup')

orig.run_compute(compute='fastcompute')

fluxes = orig.get_value('fluxes@model') + np.random.normal(size=lctimes.shape) * 0.01
fsigmas = np.ones_like(lctimes) * 0.02

rvsA = orig.get_value('rvs@primary@model') + np.random.normal(size=rvtimes.shape) * 10
rvsB = orig.get_value('rvs@secondary@model') + np.random.normal(size=rvtimes.shape) * 10
rvsigmas = np.ones_like(rvtimes) * 20




true_values=(83.5,1.2,0.8,5500)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 48.00it/s]

# %%
print(fsigmas)
# Out:
# [0.02 0.02 0.02 ... 0.02 0.02 0.02]

# %%
print(orig.filter(context='component'))
# Out:
# ParameterSet: 62 parameters
#          requiv@primary@component: 1.3 solRad
# C    requiv_max@primary@component: 2.410930801415005 solRad
#            teff@primary@component: 6500.0 K
#            abun@primary@component: 0.0
# C          logg@primary@component: 4.653053591820842
#         syncpar@primary@component: 1.0
# C        period@primary@component: 1.0 d
# C          freq@primary@component: 6.283185 rad / d
#           pitch@primary@component: 0.0 deg
#             yaw@primary@component: 0.0 deg
# C          incl@primary@component: 83.5 deg
# C       long_an@primary@component: 0.0 deg
#       gravb_bol@primary@component: 0.32
#    irrad_frac_refl_bol@primary...: 0.6
# C  irrad_frac_lost_bol@primary...: 0.4
#     ld_mode_bol@primary@component: lookup
#     ld_func_bol@primary@component: logarithmic
#    ld_coeffs_source_bol@primar...: auto
# C          mass@primary@component: 2.772507081987546 solMass
#        requiv@secondary@component: 0.9 solRad
# C  requiv_max@secondary@component: 1.9826527748101817 solRad
#          teff@secondary@component: 5500.0 K
#          abun@secondary@component: 0.0
# C        logg@secondary@component: 4.791999213097734
#       syncpar@secondary@component: 1.0
# C      period@secondary@component: 1.0 d
# C        freq@secondary@component: 6.283185 rad / d
#         pitch@secondary@component: 0.0 deg
#           yaw@secondary@component: 0.0 deg
# C        incl@secondary@component: 83.5 deg
# C     long_an@secondary@component: 0.0 deg
#     gravb_bol@secondary@component: 0.32
#    irrad_frac_refl_bol@seconda...: 0.6
# C  irrad_frac_lost_bol@seconda...: 0.4
#    ld_mode_bol@secondary@compo...: lookup
#    ld_func_bol@secondary@compo...: logarithmic
#    ld_coeffs_source_bol@second...: auto
# C        mass@secondary@component: 1.8298546741117807 solMass
#           period@binary@component: 1.0 d
# C           freq@binary@component: 6.283185 rad / d
#             dpdt@binary@component: 0.0 s / yr
#             per0@binary@component: 25.0 deg
#           dperdt@binary@component: 0.0 deg / yr
#              ecc@binary@component: 0.2
# C     t0_perpass@binary@component: -0.026614362092305888 d
#       t0_supconj@binary@component: 0.1 d
# C         t0_ref@binary@component: 0.15394119346324966 d
# C      mean_anom@binary@component: 9.581169884814848 deg
#             incl@binary@component: 83.5 deg
#                q@binary@component: 0.66
#              sma@binary@component: 7.0 solRad
#          long_an@binary@component: 0.0 deg
# C          asini@binary@component: 6.955002989736112 solRad
# C          ecosw@binary@component: 0.18126155740733
# C          esinw@binary@component: 0.0845236523481399
# C      teffratio@binary@component: 0.846153846153846
# C    requivratio@binary@component: 0.6923076923076923
# C  requivsumfrac@binary@component: 0.31428571428571433
# C           sma@primary@component: 2.783132530120482 solRad
# C         asini@primary@component: 2.765242152545683 solRad
# C         sma@secondary@component: 4.216867469879518 solRad
# C       asini@secondary@component: 4.189760837190429 solRad

# %%
print(orig.get_parameter(context='component',component='binary', qualifier='period'))
orig.get_parameter(context='component',component='binary', qualifier='period').get_description()
# Out:
# Parameter: period@binary@component
#                        Qualifier: period
#                      Description: Orbital period (defined at t0@system, sidereal: wrt the sky)
#                            Value: 1.0 d
#                   Constrained by:
#                       Constrains: t0_perpass@binary@component, t0_ref@binary@component, period_anom@binary@component, mean_anom@binary@component, freq@binary@component, mass@primary@component, period@primary@component, mass@secondary@component, period@secondary@component, compute_phases@lc01@dataset, compute_phases@rv01@dataset
#                       Related to: t0_supconj@binary@component, ecc@binary@component, per0@binary@component, dpdt@binary@component, dperdt@binary@component, t0@system, t0_perpass@binary@component, t0_ref@binary@component, period_anom@binary@component, mean_anom@binary@component, freq@binary@component, sma@binary@component, q@binary@component, mass@primary@component, syncpar@primary@component, period@primary@component, mass@secondary@component, syncpar@secondary@component, period@secondary@component, compute_times@lc01@dataset, phases_period@lc01@dataset, phases_dpdt@lc01@dataset, phases_t0@lc01@dataset, compute_phases@lc01@dataset, compute_times@rv01@dataset, phases_period@rv01@dataset, phases_dpdt@rv01@dataset, phases_t0@rv01@dataset, compute_phases@rv01@dataset
# 'Orbital period (defined at t0@system, sidereal: wrt the sky)'

# %%
print(orig.get_parameter(qualifier='pblum_mode'))
# Out:
# Parameter: pblum_mode@lc01@dataset
#                        Qualifier: pblum_mode
#                      Description: Mode for scaling passband luminosities
#                            Value: component-coupled
#                          Choices: decoupled, component-coupled, dataset-coupled, dataset-scaled, absolute
#                   Constrained by:
#                       Constrains: None
#                       Related to: None

# %%
print(orig.get_parameter(context='constraint',component='secondary', qualifier='logg'))
# Out:
# Constrains (qualifier): logg
# Expression in solar units (value): log10((({mass@secondary@component} / ({requiv@secondary@component} ** 2.000000)) * 2942.206218) * 9.319541)
# Current Result (result): 4.791999213097734

# %%
print(orig.get_parameter('mass@primary@component'))
print(orig.get_parameter('mass@secondary@component'))
# Out:
# Parameter: mass@primary@component
#                        Qualifier: mass
#                      Description: Mass
#                            Value: 2.772507081987546 solMass
#                   Constrained by: sma@binary@component, period@binary@component, q@binary@component
#                       Constrains: logg@primary@component, mass@secondary@component
#                       Related to: requiv@primary@component, logg@primary@component, sma@binary@component, period@binary@component, q@binary@component, mass@secondary@component
#
# Parameter: mass@secondary@component
#                        Qualifier: mass
#                      Description: Mass
#                            Value: 1.8298546741117807 solMass
#                   Constrained by: sma@binary@component, period@binary@component, q@binary@component
#                       Constrains: logg@secondary@component, mass@primary@component
#                       Related to: requiv@secondary@component, logg@secondary@component, sma@binary@component, period@binary@component, q@binary@component, mass@primary@component

# %% [markdown]
# ## Save Model

# %%
#orig.set_value_all('ld_mode', 'lookup')
#orig.run_compute('fastcompute')

# %%
afig, mplfig = orig.plot(x='phases', show=True)

# %%
#times = b.get_value('times', context='model')
#fluxes = b.get_value('fluxes', context='model') + np.random.normal(size=times.shape) * 0.01
#sigmas = np.ones_like(times) * 0.01

#np.savetxt('data2.lc', np.vstack((times,fluxes,sigmas)).T)

# %%
#(time_arr,flux_arr,sigma_arr) = np.loadtxt('data2.lc',unpack=True)
#plt.errorbar(time_arr,flux_arr,yerr=sigma_arr,fmt='.')

# %%
print(fluxes)
print(lctimes)
# Out:
# [1.23551049 1.22249239 1.21808255 ... 1.22886866 1.24844071 1.22247796]
# <linspace start=0.0 stop=10.0 num=1005 endpoint=True unit=None>

# %%
b = phoebe.default_binary() 
b.set_value('latex_repr', component='binary', value='orb')
b.set_value('latex_repr', component='primary', value='1')
b.set_value('latex_repr', component='secondary', value='2')

b.add_dataset('lc', 
              
compute_phases=phoebe.linspace(0,1,101),
              times=lctimes, 
              fluxes=fluxes, 
              sigmas=fsigmas, 
              dataset='lc01')


b.add_dataset('rv', 
              compute_phases=phoebe.linspace(0,1,101),
              times=rvtimes, 
              rvs={'primary': rvsA, 'secondary': rvsB}, 
              sigmas=rvsigmas,
              dataset='rv01')

b.set_value_all('ld_mode', 'lookup')

# %%
len('compute_phases@rv01@dataset')
# Out:
# 27

# %%
len('compute_phases@lc01@dataset')
# Out:
# 27

# %%
len('phases_t0@rv01@dataset')
# Out:
# 22

# %%
len('phases_t0@lc01@dataset')
# Out:
# 22

# %%
#What we Know
b.set_value('period@orbit',1)
b.set_value('teff@primary', 6500)
b.set_value('sma@binary', 7)

# %%
q_list= [0.5]
r2_list=[0.6]

# %%
#Give our best guess at the things we don't know 
b.set_value('incl@binary', 83)
b.set_value('requiv@primary', 1.3)
b.set_value('teff@secondary', 5500)
b.set_value('requiv@secondary',0.8)
b.set_value('q',0.8)

# %%
print(b.get_parameter('mass@primary@component'))
print(b.get_parameter('mass@secondary@component'))
# Out:
# Parameter: mass@primary@component
#                        Qualifier: mass
#                      Description: Mass
#                            Value: 2.556867642277404 solMass
#                   Constrained by: sma@binary@component, period@binary@component, q@binary@component
#                       Constrains: logg@primary@component, mass@secondary@component
#                       Related to: requiv@primary@component, logg@primary@component, sma@binary@component, period@binary@component, q@binary@component, mass@secondary@component
#
# Parameter: mass@secondary@component
#                        Qualifier: mass
#                      Description: Mass
#                            Value: 2.045494113821923 solMass
#                   Constrained by: sma@binary@component, period@binary@component, q@binary@component
#                       Constrains: logg@secondary@component, mass@primary@component
#                       Related to: requiv@secondary@component, logg@secondary@component, sma@binary@component, period@binary@component, q@binary@component, mass@primary@component

# %%
b.datasets
# Out:
# ['lc01', 'rv01']

# %%
print(b.filter(context='dataset',kind='rv'))
# Out:
# ParameterSet: 24 parameters
# C      compute_times@rv01@dataset: [0.   0.01 0.02 ... 0.98 0.99 1.  ] d
#       compute_phases@rv01@dataset: [0.   0.01 0.02 ... 0.98 0.99 1.  ]
#            phases_t0@rv01@dataset: t0_supconj
#         mask_enabled@rv01@dataset: True
#          mask_phases@rv01@dataset: []
#         solver_times@rv01@dataset: auto
#             passband@rv01@dataset: Johnson:V
#     intens_weighting@rv01@dataset: energy
#        times@primary@rv01@dataset: [ 0.          0.09615385  0.19230769 ...
#   9.80769231  9.90384615 10.        ] d
#      times@secondary@rv01@dataset: [ 0.          0.09615385  0.19230769 ...
#   9.80769231  9.90384615 10.        ] d
#          rvs@primary@rv01@dataset: [215.46090579 132.18504559  17.25572279 ...
#  185.72871452 249.50233229 199.56970486] km / s
#        rvs@secondary@rv01@dataset: [-120.61320742   46.09483442  174.5845322  ...
#   -81.38865294 -173.46587708 -139.44943838] km / s
#       sigmas@primary@rv01@dataset: [20. 20. 20. ... 20. 20. 20.] km / s
#     sigmas@secondary@rv01@dataset: [20. 20. 20. ... 20. 20. 20.] km / s
#    sigmas_lnf@primary@rv01@dat...: -inf
#    sigmas_lnf@secondary@rv01@d...: -inf
#    rv_offset@primary@rv01@dataset: 0.0 km / s
#    rv_offset@secondary@rv01@da...: 0.0 km / s
#      ld_mode@primary@rv01@dataset: lookup
#    ld_mode@secondary@rv01@dataset: lookup
#      ld_func@primary@rv01@dataset: logarithmic
#    ld_func@secondary@rv01@dataset: logarithmic
#    ld_coeffs_source@primary@rv...: auto
#    ld_coeffs_source@secondary@...: auto

# %%
afig, mplfig = b.plot(x='phases', show=True)
# Out:
# C:\Users\dylan\anaconda3\lib\site-packages\phoebe\dependencies\autofig\call.py:1305: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   artist = ax.scatter(*datapoint,

# %%
print(b.filter('teff'))
# Out:
# ParameterSet: 2 parameters
#            teff@primary@component: 6500.0 K
#          teff@secondary@component: 5500.0 K

# %% [markdown]
# ### Adding in rv_geometry estimator

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
b.add_solver('estimator.rv_geometry',
             rv='rv01')
# Out:
# <ParameterSet: 7 parameters | qualifiers: comments, rv_datasets, phase_nbins, expose_model, phase_bin, use_server, orbit>

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
b.run_solver(kind='rv_geometry', solution='rv_geom_sol')
# Out:
# <ParameterSet: 17 parameters | components: secondary, primary>

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
print(b.adopt_solution('rv_geom_sol', trial_run=True))
# Out:
# ParameterSet: 6 parameters
#    t0_supconj@binary@orbit@com...: 0.12046290218344285 d
#          q@binary@orbit@component: 0.67577387637741
#      asini@binary@orbit@component: 7.4717902290644895 solRad
#        ecc@binary@orbit@component: 0.14610193010691974
#       per0@binary@orbit@component: 32.99798211879587 deg
#                     vgamma@system: 80.54175075795274 km / s

# %%
print()

# %%
afig, mplfig = b.plot(solution='rv_geom_sol',
                      show=True, save='figure_rv_geometry.pdf')

# %% [markdown]
# ### Adding in lc_geometry  Estimator

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
b.add_solver('estimator.lc_geometry',
             lc='lc01')
# Out:
# <ParameterSet: 11 parameters | qualifiers: comments, phase_nbins, expose_model, phase_bin, analytical_model, use_server, interactive, lc_combine, lc_datasets, t0_near_times, orbit>

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
b.run_solver(kind='lc_geometry', solution='lc_geom_sol')
# Out:
# <ParameterSet: 21 parameters | qualifiers: fitted_units, adopt_distributions, eclipse_edges, primary_depth, secondary_depth, fitted_twigs, adopt_parameters, adopt_values, secondary_phase, primary_width, fitted_values, input_phases, analytic_best_model, comments, input_fluxes, analytic_fluxes, secondary_width, orbit, analytic_phases, primary_phase, input_sigmas>

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
print(b.adopt_solution('lc_geom_sol', trial_run=True))
# Out:
# ParameterSet: 5 parameters
#    t0_supconj@binary@orbit@com...: 0.09937733493959613 d
#        ecc@binary@orbit@component: 0.2097951309659778
#       per0@binary@orbit@component: 28.90831510564812 deg
#    requivsumfrac@binary@orbit@...: 0.3582929151463243
#    teffratio@binary@orbit@comp...: 0.7949959041312362

# %%
afig, mplfig = b.plot(solution='lc_geom_sol',
                      show=True, save='figure_lc_geometry.pdf')
# Out:
# C:\Users\dylan\anaconda3\lib\site-packages\phoebe\dependencies\autofig\call.py:1097: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array([x, y])
# C:\Users\dylan\anaconda3\lib\site-packages\phoebe\dependencies\autofig\call.py:1098: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   points = np.array([x, y]).T.reshape(-1, 1, 2)

# %%
b.solutions
# Out:
# ['rv_geom_sol', 'lc_geom_sol']

# %%
b.adopt_solution('lc_geom_sol', adopt_parameters='mask_phases')
# Out:
# <ParameterSet: 1 parameters>

# %%
_ = b.plot(context='dataset', dataset='lc01', x='phases', xlim=(-0.55,0.55),
           save='figure_lc_geometry_mask.pdf', show=True)

# %%
b.set_value('mask_enabled@lc01', False)

# %%
_ = b.plot(context='dataset', dataset='lc01', x='phases', xlim=(-0.55,0.55), show=True)

# %% [markdown]
# ### Running ebai estimator

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
b.add_solver('estimator.ebai',
             lc='lc01')
# Out:
# <ParameterSet: 8 parameters | qualifiers: ebai_method, comments, phase_nbins, phase_bin, use_server, lc_combine, lc_datasets, orbit>

# %%
b.run_solver(kind='ebai', solution='ebai_sol')
# Out:
# <ParameterSet: 13 parameters | qualifiers: comments, fitted_twigs, fitted_units, adopt_parameters, input_fluxes, adopt_values, adopt_distributions, input_sigmas, ebai_fluxes, fitted_values, input_phases, ebai_phases, orbit>

# %%
print(b.filter( 'input_sigmas@ebai01@ebai_sol'))
# Out:
# ParameterSet: 1 parameters
# R  input_sigmas@ebai01@ebai_so...: [0.00479346 0.00869917 0.00119444
#  ... 0.00281157 0.00761807
#  0.00543614]

# %%
print(b.adopt_solution('ebai_sol', trial_run=True))
# Out:
# ParameterSet: 6 parameters
#    t0_supconj@binary@orbit@com...: 0.09979880478087627 d
#    teffratio@binary@orbit@comp...: 0.8068492564775768
#    requivsumfrac@binary@orbit@...: 0.3353278527888415
#      esinw@binary@orbit@component: 0.12228557591824457
#      ecosw@binary@orbit@component: 0.15245133652211887
#       incl@binary@orbit@component: 80.9396998020446 deg

# %%
print(b.get_solution('ebai_sol').filter(qualifier=['message', 'nfev', 'niter', 'success']))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
afig, mplfig = b.plot(solution='ebai_sol',
                      show=True, save='figure_ebai.pdf')
# Out:
# C:\Users\dylan\anaconda3\lib\site-packages\phoebe\dependencies\autofig\call.py:1305: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   artist = ax.scatter(*datapoint,

# %% [markdown]
# ### Adopting solutions from RV and LC estimators

# %%
b.flip_constraint('asini@binary', solve_for='sma@binary')
b.adopt_solution('rv_geom_sol')
# Out:
# <ParameterSet: 26 parameters | contexts: dataset, component, system>

# %%
print(b.filter('q@binary@orbit@component'))
# Out:
# ParameterSet: 1 parameters
#                q@binary@component: 0.67577387637741

# %%
print(b.filter(qualifier='per0',component='binary'))
# Out:
# ParameterSet: 1 parameters
#             per0@binary@component: 32.99798211879587 deg

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11276\2447702307.py in <module>
# ----> 1 b.adopt_solution('lc_geom_sol')
#
# ~\anaconda3\lib\site-packages\phoebe\frontend\bundle.py in adopt_solution(self, solution, adopt_parameters, adopt_distributions, adopt_values, trial_run, remove_solution, return_changes, **kwargs)
#   13807
#   13808         if not kwargs.get('skip_checks', False):
# > 13809             self.run_checks_solution(solution=solution_ps.solution,
#   13810                                      raise_logger_warning=True, raise_error=True,
#   13811                                      adopt_parameters=adopt_parameters,
#
# ~\anaconda3\lib\site-packages\phoebe\frontend\bundle.py in run_checks_solution(self, solution, compute, solver, figure, raise_logger_warning, raise_error, **kwargs)
#    5064
#    5065
# -> 5066         self._run_checks_warning_error(report, raise_logger_warning, raise_error)
#    5067
#    5068         return report
#
# ~\anaconda3\lib\site-packages\phoebe\frontend\bundle.py in _run_checks_warning_error(self, report, raise_logger_warning, raise_error)
#    3221         if raise_error:
#    3222             if not report.passed:
# -> 3223                 raise ValueError("failed to pass checks\n{}".format(report))
#    3224
#    3225     def run_checks(self, raise_logger_warning=False, raise_error=False, **kwargs):
#
# ValueError: failed to pass checks
# Run Checks Report: FAIL
# ERROR: requivsumfrac@binary@orbit@component is currently constrained but cannot automatically temporarily flip as solve_for has several options (requiv@primary@star@component, requiv@secondary@star@component, sma@binary@orbit@component).  Flip the constraint manually first, set adopt_values=False, or remove requivsumfrac@binary@orbit@component from adopt_parameters. (3 affected parameters, affecting adopt_solution)
# ERROR: teffratio@binary@orbit@component is currently constrained but cannot automatically temporarily flip as solve_for has several options (teff@secondary@star@component, teff@primary@star@component).  Flip the constraint manually first, set adopt_values=False, or remove teffratio@binary@orbit@component from adopt_parameters. (3 affected parameters, affecting adopt_solution)

# %%
print(b.filter(qualifier='per0',component='binary'))
# Out:
# ParameterSet: 1 parameters
#             per0@binary@component: 32.99798211879587 deg

# %% [markdown]
# ### Adopting solution from ebai estimator

# %%
b.flip_constraint('teffratio', solve_for='teff@secondary')
b.flip_constraint('requivsumfrac', solve_for='requiv@primary')
# Out:
# <ConstraintParameter: {requiv@primary@component} = ({requivsumfrac@binary@component} * {sma@binary@component}) - {requiv@secondary@component} (solar units) => 1.3 solRad>

# %%
b.adopt_solution('ebai_sol', adopt_parameters=['teffratio', 'requivsumfrac', 'incl'])
# Out:
# <ParameterSet: 19 parameters | kinds: star, orbit>

# %%
b.adopt_solution('lc_geom_sol')
# Out:
# <ParameterSet: 18 parameters | contexts: dataset, component>

# %%
print(b.filter(qualifier=['logg'], context='component'))
# Out:
# ParameterSet: 2 parameters
# C          logg@primary@component: 4.4156891012705755
# C        logg@secondary@component: 5.001792420986315

# %%
print(b.filter(qualifier=['ecc', 'per0', 'teff', 'sma', 'incl', 'q', 'requiv','mass','logg'], context='component'))
b.save('success_ebai_run3_q_0.5_1.0_5550.bundle')
# Out:
# ParameterSet: 17 parameters
# C        requiv@primary@component: 1.9109131423276369 solRad
#            teff@primary@component: 6500.0 K
# C          logg@primary@component: 4.4156891012705755
# C          incl@primary@component: 80.9396998020446 deg
# C          mass@primary@component: 3.4681938486141575 solMass
#        requiv@secondary@component: 0.8 solRad
# C        teff@secondary@component: 5167.473376853036 K
# C        logg@secondary@component: 5.001792420986315
# C        incl@secondary@component: 80.9396998020446 deg
# C        mass@secondary@component: 2.3437148011062776 solMass
#             per0@binary@component: 28.90831510564812 deg
#              ecc@binary@component: 0.2097951309659778
#             incl@binary@component: 80.9396998020446 deg
#                q@binary@component: 0.67577387637741
# C            sma@binary@component: 7.5661924300694565 solRad
# C           sma@primary@component: 3.0511486424042564 solRad
# C         sma@secondary@component: 4.5150437876652 solRad
# 'success_ebai_run3_q_0.5_1.0_5550.bundle'

# %%
print(b.filter(qualifier=['ecc', 'per0', 'teff', 'sma', 'incl', 'q', 'requiv','mass','logg'], context='component'))
# Out:
# ParameterSet: 17 parameters
# C        requiv@primary@component: 1.9109131423276369 solRad
#            teff@primary@component: 6500.0 K
# C          logg@primary@component: 4.4156891012705755
# C          incl@primary@component: 80.9396998020446 deg
# C          mass@primary@component: 3.4681938486141575 solMass
#        requiv@secondary@component: 0.8 solRad
# C        teff@secondary@component: 5167.473376853036 K
# C        logg@secondary@component: 5.001792420986315
# C        incl@secondary@component: 80.9396998020446 deg
# C        mass@secondary@component: 2.3437148011062776 solMass
#             per0@binary@component: 28.90831510564812 deg
#              ecc@binary@component: 0.2097951309659778
#             incl@binary@component: 80.9396998020446 deg
#                q@binary@component: 0.67577387637741
# C            sma@binary@component: 7.5661924300694565 solRad
# C           sma@primary@component: 3.0511486424042564 solRad
# C         sma@secondary@component: 4.5150437876652 solRad

# %%
b.set_value_all('pblum_mode', 'dataset-scaled')

# %%
b.get_parameter(context='compute', qualifier='irrad_method').set_value("none")

# %%
print(b.get_solution('ebai_sol').filter(qualifier=['message', 'nfev', 'niter', 'success']))
# Out:
# ParameterSet: 0 parameters
# NO PARAMETERS

# %%
#b.set_value(qualifier='ld_func',dataset='lc01', component='primary', value='linear', overwrite=True)
#b.set_value(qualifier='ld_func',dataset='lc01', component='secondary', value='linear', overwrite=True)


#b.set_value(qualifier='ld_func',dataset='rv01', component='primary', value='linear', overwrite=True)
#b.set_value(qualifier='ld_func',dataset='rv01', component='secondary', value='linear', overwrite=True)

# %%
#b.set_value(qualifier='ld_mode', dataset='lc01', component='primary', value='manual',overwrite=True )
#b.set_value(qualifier='ld_mode', dataset='lc01', component='secondary', value='manual',overwrite=True)


#b.set_value(qualifier='ld_mode', dataset='rv01', component='primary', value='manual',overwrite=True )
#b.set_value(qualifier='ld_mode', dataset='rv01', component='secondary', value='manual',overwrite=True)

# %%
b.run_compute(irrad_method='none', model='after_estimators', overwrite=True)

# %%
_ = b.plot(x='phases', m='.', show=True)

# %% [markdown]
# ### Adding in nelder-mead optimizer

# %%
b.add_compute('ellc', compute='fastcompute')

# %%
b.add_solver('optimizer.nelder_mead',
             fit_parameters=['teffratio', 'requivsumfrac', 'incl@binary', 'q', 'ecc', 'per0'],
             compute='fastcompute')

# %%
print(b.get_solver(kind='nelder_mead'))

# %%
b.run_solver(kind='nelder_mead', maxiter=10000, solution='nm_sol',overwrite=True)

# %%
print(b.get_value(solution=('nm_sol'), qualifier='success'))

# %%
print(b.get_solution('nm_sol').filter(qualifier=[ 'success']))

# %%
print(b.adopt_solution('nm_sol', trial_run=True))

# %%
b.adopt_solution('nm_sol')

# %%
b.run_compute(compute='fastcompute',model='after_nm')

# %%
_ = b.plot(x='phases', 
           c={'after_estimators': 'red', 'after_nm': 'green', 'dataset': 'black'}, 
           linestyle={'after_estimators': 'dashed', 'after_nm': 'solid'},
           marker={'dataset': '.'},
           save='figure_optimizer_nm.pdf', show=True)

# %%
b.run_compute(compute='phoebe01', model='after_nm_phoebe')

# %%
_ = b.plot(x='phases', model='after_nm*', show=True)

# %%
print(b.filter(qualifier=['ecc', 'per0', 'teff', 'sma', 'incl', 'q', 'requiv','logg'], context='component'))
b.save('success_nelder_run3_q_0.5_r2_1.0_5550.bundle')

# %%
import corner

# Replace the following list with the parameters you want to plot
params = [b.get_value('ecc'),
          b.get_value('per0'),
          b.get_value('teff@primary'),
          b.get_value('teff@secondary'),
          b.get_value('sma@binary'),
          b.get_value('incl@binary'),
          b.get_value('q'),
          b.get_value('requiv@primary'),
          b.get_value('requiv@secondary')]

# Create a corner plot
fig = corner.corner(params, labels=['ecc', 'per0', 'teff@primary', 'teff@secondary', 'sma@binary', 'incl@binary', 'q', 'requiv@primary', 'requiv@secondary'])

# Show the plot
plt.show()
